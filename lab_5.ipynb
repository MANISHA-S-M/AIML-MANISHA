# %% [markdown]
# <a href="https://colab.research.google.com/github/MANISHA-S-M/AIML-MANISHA/blob/main/lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

data = pd.read_csv("/content/Labsheet 5 Sales.csv")

# %%
x=data['GrLivArea']
y=data['SalePrice']

x=(x-x.mean()) /x.std()
x=np.c_[np.ones(x.shape[0]), x]

# %%
alpha = 0.01
iterations = 2000
m = y .size
np.random.seed(123)
theta = np.random.rand(2)

# %%
def gradient_descent(x,y,theta,iterations,alpha):
  past_costs=[]
  past_thetas=[theta]
  for i in range(iterations):
    prediction = np.dot(x,theta)
    error=prediction-y
    cost=1/(2*m) * np.dot(error.T, error)
    past_costs.append(cost)
    theta=theta-(alpha*(1/m)*np.dot(x.T,error))
    past_thetas.append(theta)
  return past_thetas,past_costs

past_thetas,past_costs=gradient_descent(x,y,theta,iterations,alpha)
theta=past_thetas[-1]

print("Gradient Descent: {:.2f},{:.2f}".format(theta[0],theta[1]))
# Out:
# Gradient Descent: 180921.20,56294.90

# %%
plt.title('Cost function J')
plt.xlabel('No of iterations')
plt.ylabel('cost')
plt.plot(past_costs)
plt.show()

# %%
#set plot up,
fig=plt.figure()
ax=plt.axes()
plt.title('Sale Price vs Living Area')
plt.xlabel('Living Area in square feet (scaled)')
plt.ylabel('Sale Price ($)')
plt.scatter(x[:,1],y, color='red')
line, =ax.plot([],[], lw=2)
annotation=ax.text(-1,700000,'')
annotation.set_animated(True)
plt.close()

# %%
#Import the matplotlib.animation module and rename it to animation
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation #Import the FuncAnimation object from matplotlib.animation
import matplotlib.pyplot as plt
import numpy as np

def animate(i):
  x=np.linspace(-5,20,1000)
  y=past_thetas[i][1]*x+past_thetas[i][0]
  line.set_data(x,y)
  annotation.set_text('Cost = %.2f e10' % (past_costs[i]/100000000))
  return line,annotation

# define the init function
def init():
    line.set_data([], [])
    annotation.set_text('')
    return line, annotation


anim=FuncAnimation(fig, animate, init_func=init,frames=300,interval=0,blit=True)
anim.save('animation.gif',writer='imagemagick',fps=30)
# Out:
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.

# %%
# !pip install imagemagick
#Import the matplotlib.animation module and rename it to animation
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation #Import the FuncAnimation object from matplotlib.animation
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ERROR: Could not find a version that satisfies the requirement imagemagick (from versions: none)
# ERROR: No matching distribution found for imagemagick

# %%
def animate(i):
  x=np.linspace(-5,20,1000)
  y=past_thetas[i][1]*x+past_thetas[i][0]
  line.set_data(x,y)
  annotation.set_text('Cost = %.2f e10' % (past_costs[i]/100000000))
  return line,annotation

anim=FuncAnimation(fig, animate, init_func=init,frames=300,interval=0,blit=True)
anim.save('animation.gif',writer='imagemagick',fps=30)
# Out:
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.

# %%
#Display the animation...
import io
import base64
from IPython.display import HTML

filename = 'animation.gif'

video = io.open(filename, 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<img src="data:image/gif;base64,{0}" type="gif" />'''.format(encoded.decode('ascii')))
# Out:
# <img src="data:image/gif;base64,..." type="gif" />
